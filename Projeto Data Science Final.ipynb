# %% [markdown]
# ## Projeto: 120 anos das Olimpiadas
# ###### Por: Rafael Albuquerque 26/01/2024

# %%
import pandas as pd

# %%
atleta = pd.read_csv('C:/Users/rafae/Documents/Projeto Final - Impacta/athlete_events.csv',sep=',',encoding='UTF-8')

# %%
regiao = pd.read_csv('C:/Users/rafae/Documents/Projeto Final - Impacta/noc_regions.csv',sep=',',encoding='UTF-8')

# %%
atleta.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
regiao.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
olim = pd.merge(atleta, regiao, on='NOC', how='left')

# %%
olim.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
olim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.2+ MB

# %%
olim.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region', 'notes'],
#       dtype='object')

# %%
olim = olim.rename(columns={'Name' : 'Nome', 'Sex' : 'Sexo', 'Age' : 'Idade', 'Height' : 'Altura', 'Weight' : 'Peso', 'Team' : 'Time', 'NOC' : 'Sigla', 'Games' : 'Jogos',
       'Year' : 'Ano', 'Season' : 'Temporada', 'City' : 'Cidade', 'Sport' : 'Esporte', 'Event' : 'Evento', 'Medal' : 'Medalha', 'region' : 'País', 'notes': 'Observações'})

# %%
olim.head()
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso            Time  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0           China
# 1   2                  A Lamusi    M   23.0   170.0  60.0           China
# 2   3       Gunnar Nielsen Aaby    M   24.0     NaN   NaN         Denmark
# 3   4      Edgar Lindenau Aabye    M   34.0     NaN   NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0     Netherlands
#
#   Sigla        Jogos   Ano Temporada     Cidade        Esporte  \
# 0   CHN  1992 Summer  1992    Summer  Barcelona     Basketball
# 1   CHN  2012 Summer  2012    Summer     London           Judo
# 2   DEN  1920 Summer  1920    Summer  Antwerpen       Football
# 3   DEN  1900 Summer  1900    Summer      Paris     Tug-Of-War
# 4   NED  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                              Evento Medalha         País Observações
# 0       Basketball Men's Basketball     NaN        China         NaN
# 1      Judo Men's Extra-Lightweight     NaN        China         NaN
# 2           Football Men's Football     NaN      Denmark         NaN
# 3       Tug-Of-War Men's Tug-Of-War    Gold      Denmark         NaN
# 4  Speed Skating Women's 500 metres     NaN  Netherlands         NaN

# %%
olim = olim.rename(columns={'Sigla Pais' : 'Sigla'})

# %%
olim.head(5)
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso            Time  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0           China
# 1   2                  A Lamusi    M   23.0   170.0  60.0           China
# 2   3       Gunnar Nielsen Aaby    M   24.0     NaN   NaN         Denmark
# 3   4      Edgar Lindenau Aabye    M   34.0     NaN   NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0     Netherlands
#
#   Sigla        Jogos   Ano Temporada     Cidade        Esporte  \
# 0   CHN  1992 Summer  1992    Summer  Barcelona     Basketball
# 1   CHN  2012 Summer  2012    Summer     London           Judo
# 2   DEN  1920 Summer  1920    Summer  Antwerpen       Football
# 3   DEN  1900 Summer  1900    Summer      Paris     Tug-Of-War
# 4   NED  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                              Evento Medalha         País Observações
# 0       Basketball Men's Basketball     NaN        China         NaN
# 1      Judo Men's Extra-Lightweight     NaN        China         NaN
# 2           Football Men's Football     NaN      Denmark         NaN
# 3       Tug-Of-War Men's Tug-Of-War    Gold      Denmark         NaN
# 4  Speed Skating Women's 500 metres     NaN  Netherlands         NaN

# %%
olim.shape
# Out:
# (271116, 17)

# %%
olim = olim.drop_duplicates()

# %%
olim.shape
# Out:
# (269731, 17)

# %%
olim.head(5)
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso            Time  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0           China
# 1   2                  A Lamusi    M   23.0   170.0  60.0           China
# 2   3       Gunnar Nielsen Aaby    M   24.0     NaN   NaN         Denmark
# 3   4      Edgar Lindenau Aabye    M   34.0     NaN   NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0     Netherlands
#
#   Sigla        Jogos   Ano Temporada     Cidade        Esporte  \
# 0   CHN  1992 Summer  1992    Summer  Barcelona     Basketball
# 1   CHN  2012 Summer  2012    Summer     London           Judo
# 2   DEN  1920 Summer  1920    Summer  Antwerpen       Football
# 3   DEN  1900 Summer  1900    Summer      Paris     Tug-Of-War
# 4   NED  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                              Evento Medalha         País Observações
# 0       Basketball Men's Basketball     NaN        China         NaN
# 1      Judo Men's Extra-Lightweight     NaN        China         NaN
# 2           Football Men's Football     NaN      Denmark         NaN
# 3       Tug-Of-War Men's Tug-Of-War    Gold      Denmark         NaN
# 4  Speed Skating Women's 500 metres     NaN  Netherlands         NaN

# %%
olim.isnull().all()
# Out:
# ID             False
# Nome           False
# Sexo           False
# Idade          False
# Altura         False
# Peso           False
# Time           False
# Sigla          False
# Jogos          False
# Ano            False
# Temporada      False
# Cidade         False
# Esporte        False
# Evento         False
# Medalha        False
# País           False
# Observações    False
# dtype: bool

# %%
olim.isnull().any()
# Out:
# ID             False
# Nome           False
# Sexo           False
# Idade           True
# Altura          True
# Peso            True
# Time           False
# Sigla          False
# Jogos          False
# Ano            False
# Temporada      False
# Cidade         False
# Esporte        False
# Evento         False
# Medalha         True
# País            True
# Observações     True
# dtype: bool

# %%
olim[olim['Altura'].isnull()]
# Out:
#             ID                             Nome Sexo  Idade  Altura  Peso  \
# 2            3              Gunnar Nielsen Aaby    M   24.0     NaN   NaN
# 3            4             Edgar Lindenau Aabye    M   34.0     NaN   NaN
# 29          10   Einar Ferdinand "Einari" Aalto    M   26.0     NaN   NaN
# 35          15             Arvo Ossian Aaltonen    M   22.0     NaN   NaN
# 36          15             Arvo Ossian Aaltonen    M   22.0     NaN   NaN
# ...        ...                              ...  ...    ...     ...   ...
# 271038  135539            Marius Edmund Zwiller    M   18.0     NaN   NaN
# 271042  135542                   Werner Zwingli    M   29.0     NaN   NaN
# 271043  135542                   Werner Zwingli    M   29.0     NaN   NaN
# 271075  135552  Jan (Johann-) Zybert (Siebert-)    M   20.0     NaN   NaN
# 271100  135561                    Frantiek Zyka    M   26.0     NaN   NaN
#
#                   Time Sigla        Jogos   Ano Temporada             Cidade  \
# 2              Denmark   DEN  1920 Summer  1920    Summer          Antwerpen
# 3       Denmark/Sweden   DEN  1900 Summer  1900    Summer              Paris
# 29             Finland   FIN  1952 Summer  1952    Summer           Helsinki
# 35             Finland   FIN  1912 Summer  1912    Summer          Stockholm
# 36             Finland   FIN  1912 Summer  1912    Summer          Stockholm
# ...                ...   ...          ...   ...       ...                ...
# 271038          France   FRA  1924 Summer  1924    Summer              Paris
# 271042     Switzerland   SUI  1956 Winter  1956    Winter  Cortina d'Ampezzo
# 271043     Switzerland   SUI  1956 Winter  1956    Winter  Cortina d'Ampezzo
# 271075          Poland   POL  1928 Summer  1928    Summer          Amsterdam
# 271100  Czechoslovakia   TCH  1928 Summer  1928    Summer          Amsterdam
#
#                      Esporte  \
# 2                   Football
# 3                 Tug-Of-War
# 29                  Swimming
# 35                  Swimming
# 36                  Swimming
# ...                      ...
# 271038              Swimming
# 271042  Cross Country Skiing
# 271043  Cross Country Skiing
# 271075               Cycling
# 271100             Athletics
#
#                                                    Evento Medalha  \
# 2                                 Football Men's Football     NaN
# 3                             Tug-Of-War Men's Tug-Of-War    Gold
# 29                    Swimming Men's 400 metres Freestyle     NaN
# 35                 Swimming Men's 200 metres Breaststroke     NaN
# 36                 Swimming Men's 400 metres Breaststroke     NaN
# ...                                                   ...     ...
# 271038             Swimming Men's 200 metres Breaststroke     NaN
# 271042           Cross Country Skiing Men's 15 kilometres     NaN
# 271043  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 271075           Cycling Men's Team Pursuit, 4,000 metres     NaN
# 271100                           Athletics Men's Marathon     NaN
#
#                   País Observações
# 2              Denmark         NaN
# 3              Denmark         NaN
# 29             Finland         NaN
# 35             Finland         NaN
# 36             Finland         NaN
# ...                ...         ...
# 271038          France         NaN
# 271042     Switzerland         NaN
# 271043     Switzerland         NaN
# 271075          Poland         NaN
# 271100  Czech Republic         NaN
#
# [58814 rows x 17 columns]

# %%
olim.isnull().sum()
# Out:
# ID                  0
# Nome                0
# Sexo                0
# Idade            9315
# Altura          58814
# Peso            61527
# Time                0
# Sigla               0
# Jogos               0
# Ano                 0
# Temporada           0
# Cidade              0
# Esporte             0
# Evento              0
# Medalha        229959
# País              370
# Observações    264696
# dtype: int64

# %%
olim = olim.dropna(subset=['Peso'])

# %%
olim.isnull().sum()
# Out:
# ID                  0
# Nome                0
# Sexo                0
# Idade             862
# Altura           1364
# Peso                0
# Time                0
# Sigla               0
# Jogos               0
# Ano                 0
# Temporada           0
# Cidade              0
# Esporte             0
# Evento              0
# Medalha        177748
# País              277
# Observações    204692
# dtype: int64

# %%
olim = olim.dropna(subset=['Altura'])

# %%
olim.isnull().sum()
# Out:
# ID                  0
# Nome                0
# Sexo                0
# Idade             688
# Altura              0
# Peso                0
# Time                0
# Sigla               0
# Jogos               0
# Ano                 0
# Temporada           0
# Cidade              0
# Esporte             0
# Evento              0
# Medalha        176644
# País              270
# Observações    203346
# dtype: int64

# %%
olim = olim.dropna(subset=['Idade'])

# %%
olim.isnull().sum()
# Out:
# ID                  0
# Nome                0
# Sexo                0
# Idade               0
# Altura              0
# Peso                0
# Time                0
# Sigla               0
# Jogos               0
# Ano                 0
# Temporada           0
# Cidade              0
# Esporte             0
# Evento              0
# Medalha        175971
# País              270
# Observações    202659
# dtype: int64

# %%
olim_remover = olim

# %%
olim_remover.shape
# Out:
# (206152, 17)

# %%
olim_remover = olim_remover.dropna(axis=1, how = 'all')

# %%
olim_remover.shape
# Out:
# (206152, 17)

# %%
olim_remover = olim_remover.dropna(axis=1, how = 'any')

# %%
olim_remover.shape
# Out:
# (206152, 14)

# %%
olim_remover.head(3)
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso         Time Sigla  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0        China   CHN
# 1   2                  A Lamusi    M   23.0   170.0  60.0        China   CHN
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0  Netherlands   NED
#
#          Jogos   Ano Temporada     Cidade        Esporte  \
# 0  1992 Summer  1992    Summer  Barcelona     Basketball
# 1  2012 Summer  2012    Summer     London           Judo
# 4  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                              Evento
# 0       Basketball Men's Basketball
# 1      Judo Men's Extra-Lightweight
# 4  Speed Skating Women's 500 metres

# %%
olim.shape
# Out:
# (206152, 17)

# %%
olim['Sexo'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
olim['Cidade'].unique()
# Out:
# array(['Barcelona', 'London', 'Calgary', 'Albertville', 'Lillehammer',
#        'Salt Lake City', 'Lake Placid', 'Sydney', 'Atlanta', 'Sochi',
#        'Helsinki', 'Nagano', 'Torino', 'Rio de Janeiro', 'Athina',
#        'Sarajevo', 'Mexico City', 'Munich', 'Berlin', 'Melbourne', 'Roma',
#        'Antwerpen', 'Paris', 'Amsterdam', 'Beijing', 'Montreal', 'Seoul',
#        'Moskva', 'Los Angeles', 'Tokyo', 'Vancouver', 'Innsbruck',
#        'Grenoble', 'Sapporo', 'Chamonix', 'Stockholm',
#        'Garmisch-Partenkirchen', 'Sankt Moritz', "Cortina d'Ampezzo",
#        'Squaw Valley', 'Oslo', 'St. Louis'], dtype=object)

# %%
olim['Sexo'].value_counts()
# Out:
# Sexo
# M    139441
# F     66711
# Name: count, dtype: int64

# %%
olim['Cidade'].value_counts()
# Out:
# Cidade
# London                    13803
# Sydney                    13682
# Athina                    13640
# Rio de Janeiro            13443
# Beijing                   13402
# Atlanta                   11838
# Seoul                     11618
# Barcelona                 10326
# Munich                     9847
# Los Angeles                9356
# Mexico City                8402
# Montreal                   8265
# Roma                       7526
# Tokyo                      7368
# Moskva                     6843
# Sochi                      4673
# Vancouver                  4378
# Torino                     4365
# Salt Lake City             4060
# Nagano                     3518
# Lillehammer                2971
# Albertville                2783
# Innsbruck                  2645
# Melbourne                  2155
# Calgary                    2018
# Sarajevo                   1951
# Helsinki                   1914
# Grenoble                   1801
# Sapporo                    1635
# Lake Placid                1417
# Berlin                      827
# Stockholm                   657
# Amsterdam                   621
# Paris                       613
# Squaw Valley                512
# Antwerpen                   428
# Cortina d'Ampezzo           334
# Sankt Moritz                146
# Oslo                        144
# St. Louis                   119
# Garmisch-Partenkirchen       69
# Chamonix                     39
# Name: count, dtype: int64

# %%
olim['Sexo'].value_counts(normalize=True)
# Out:
# Sexo
# M    0.676399
# F    0.323601
# Name: proportion, dtype: float64

# %%
olim['Cidade'].value_counts(normalize=True)
# Out:
# Cidade
# London                    0.066955
# Sydney                    0.066369
# Athina                    0.066165
# Rio de Janeiro            0.065209
# Beijing                   0.065010
# Atlanta                   0.057424
# Seoul                     0.056356
# Barcelona                 0.050089
# Munich                    0.047766
# Los Angeles               0.045384
# Mexico City               0.040756
# Montreal                  0.040092
# Roma                      0.036507
# Tokyo                     0.035741
# Moskva                    0.033194
# Sochi                     0.022668
# Vancouver                 0.021237
# Torino                    0.021174
# Salt Lake City            0.019694
# Nagano                    0.017065
# Lillehammer               0.014412
# Albertville               0.013500
# Innsbruck                 0.012830
# Melbourne                 0.010453
# Calgary                   0.009789
# Sarajevo                  0.009464
# Helsinki                  0.009284
# Grenoble                  0.008736
# Sapporo                   0.007931
# Lake Placid               0.006874
# Berlin                    0.004012
# Stockholm                 0.003187
# Amsterdam                 0.003012
# Paris                     0.002974
# Squaw Valley              0.002484
# Antwerpen                 0.002076
# Cortina d'Ampezzo         0.001620
# Sankt Moritz              0.000708
# Oslo                      0.000699
# St. Louis                 0.000577
# Garmisch-Partenkirchen    0.000335
# Chamonix                  0.000189
# Name: proportion, dtype: float64

# %%
olim.sort_values(by='Cidade')
# Out:
#             ID                Nome Sexo  Idade  Altura   Peso            Time  \
# 101087   51116      Hur Seung-Wook    M   19.0   173.0   89.0     South Korea
# 251056  125746       Bart Veldkamp    M   24.0   181.0   84.0     Netherlands
# 27788    14419      Philippe Bozon    M   25.0   180.0   87.0          France
# 251055  125746       Bart Veldkamp    M   24.0   181.0   84.0     Netherlands
# 103975   52617  Jari Olavi Isomets    M   23.0   175.0   64.0         Finland
# ...        ...                 ...  ...    ...     ...    ...             ...
# 137367   69058         Evelyne Leu    F   33.0   167.0   62.0     Switzerland
# 105422   53325          Jaromr Jgr    M   37.0   189.0  102.0  Czech Republic
# 49123    25296         Maria Danou    F   19.0   168.0   52.0          Greece
# 124838   63019  Markku Olavi Koski    M   28.0   181.0   73.0         Finland
# 96540    48877  Odd-Bjrn Hjelmeset    M   38.0   180.0   69.0          Norway
#
#        Sigla        Jogos   Ano Temporada       Cidade               Esporte  \
# 101087   KOR  1992 Winter  1992    Winter  Albertville         Alpine Skiing
# 251056   NED  1992 Winter  1992    Winter  Albertville         Speed Skating
# 27788    FRA  1992 Winter  1992    Winter  Albertville            Ice Hockey
# 251055   NED  1992 Winter  1992    Winter  Albertville         Speed Skating
# 103975   FIN  1992 Winter  1992    Winter  Albertville  Cross Country Skiing
# ...      ...          ...   ...       ...          ...                   ...
# 137367   SUI  2010 Winter  2010    Winter    Vancouver      Freestyle Skiing
# 105422   CZE  2010 Winter  2010    Winter    Vancouver            Ice Hockey
# 49123    GRE  2010 Winter  2010    Winter    Vancouver  Cross Country Skiing
# 124838   FIN  2010 Winter  2010    Winter    Vancouver          Snowboarding
# 96540    NOR  2010 Winter  2010    Winter    Vancouver  Cross Country Skiing
#
#                                             Evento Medalha            País  \
# 101087                  Alpine Skiing Men's Slalom     NaN     South Korea
# 251056            Speed Skating Men's 5,000 metres     NaN     Netherlands
# 27788                  Ice Hockey Men's Ice Hockey     NaN          France
# 251055            Speed Skating Men's 1,500 metres     NaN     Netherlands
# 103975    Cross Country Skiing Men's 10 kilometres     NaN         Finland
# ...                                            ...     ...             ...
# 137367            Freestyle Skiing Women's Aerials     NaN     Switzerland
# 105422                 Ice Hockey Men's Ice Hockey     NaN  Czech Republic
# 49123   Cross Country Skiing Women's 10 kilometres     NaN          Greece
# 124838                 Snowboarding Men's Halfpipe     NaN         Finland
# 96540     Cross Country Skiing Men's 50 kilometres     NaN          Norway
#
#        Observações
# 101087         NaN
# 251056         NaN
# 27788          NaN
# 251055         NaN
# 103975         NaN
# ...            ...
# 137367         NaN
# 105422         NaN
# 49123          NaN
# 124838         NaN
# 96540          NaN
#
# [206152 rows x 17 columns]

# %%
# Atleta mais alto
olim['Altura'].max()
# Out:
# 226.0

# %%
# Atleta mais pesado
olim['Peso'].max()
# Out:
# 214.0

# %%
# Idade mais alta 
olim['Idade'].max()
# Out:
# 71.0

# %%
# Altura Média
olim['Altura'].mean()
# Out:
# 175.3720555706469

# %%
olim['Altura'].describe()
# Out:
# count    206152.000000
# mean        175.372056
# std          10.545816
# min         127.000000
# 25%         168.000000
# 50%         175.000000
# 75%         183.000000
# max         226.000000
# Name: Altura, dtype: float64

# %%
olim['Idade'].describe()
# Out:
# count    206152.000000
# mean         25.054736
# std           5.481679
# min          11.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          71.000000
# Name: Idade, dtype: float64

# %%
# 5 Maiores atletas
olim['Altura'].sort_values(ascending=False).head(5)
# Out:
# 265042    226.0
# 265041    226.0
# 265040    226.0
# 32376     223.0
# 207375    223.0
# Name: Altura, dtype: float64

# %%
# 5 Menores atletas
olim['Altura'].sort_values(ascending=True).head(5)
# Out:
# 29333     127.0
# 29334     127.0
# 29335     127.0
# 29336     127.0
# 164821    127.0
# Name: Altura, dtype: float64

# %%
olim[olim['Altura']> 200].head()
# Out:
#       ID                        Nome Sexo  Idade  Altura   Peso  \
# 299  161              Hossam Abdalla    M   28.0   203.0   97.0
# 443  246          Mamdouh Abdelrehim    M   26.0   207.0   90.0
# 609  351  Julius Shareef Abdur-Rahim    M   23.0   202.0  104.0
# 820  468    Abdelhalim Muhammad Abou    M   27.0   210.0   88.0
# 833  474     Essameldin Abou El-Nein    M   29.0   205.0  102.0
#
#               Time Sigla        Jogos   Ano Temporada          Cidade  \
# 299          Egypt   EGY  2016 Summer  2016    Summer  Rio de Janeiro
# 443          Egypt   EGY  2016 Summer  2016    Summer  Rio de Janeiro
# 609  United States   USA  2000 Summer  2000    Summer          Sydney
# 820          Egypt   EGY  2016 Summer  2016    Summer  Rio de Janeiro
# 833          Egypt   EGY  1984 Summer  1984    Summer     Los Angeles
#
#         Esporte                       Evento Medalha   País Observações
# 299  Volleyball  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 443  Volleyball  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 609  Basketball  Basketball Men's Basketball    Gold    USA         NaN
# 820  Volleyball  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 833  Basketball  Basketball Men's Basketball     NaN  Egypt         NaN

# %%
olim.head(40)
# Out:
#     ID                            Nome Sexo  Idade  Altura  Peso  \
# 0    1                       A Dijiang    M   24.0   180.0  80.0
# 1    2                        A Lamusi    M   23.0   170.0  60.0
# 4    5        Christine Jacoba Aaftink    F   21.0   185.0  82.0
# 5    5        Christine Jacoba Aaftink    F   21.0   185.0  82.0
# 6    5        Christine Jacoba Aaftink    F   25.0   185.0  82.0
# 7    5        Christine Jacoba Aaftink    F   25.0   185.0  82.0
# 8    5        Christine Jacoba Aaftink    F   27.0   185.0  82.0
# 9    5        Christine Jacoba Aaftink    F   27.0   185.0  82.0
# 10   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 11   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 12   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 13   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 14   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 15   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 16   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 17   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 18   7                    John Aalberg    M   31.0   183.0  72.0
# 19   7                    John Aalberg    M   31.0   183.0  72.0
# 20   7                    John Aalberg    M   31.0   183.0  72.0
# 21   7                    John Aalberg    M   31.0   183.0  72.0
# 22   7                    John Aalberg    M   33.0   183.0  72.0
# 23   7                    John Aalberg    M   33.0   183.0  72.0
# 24   7                    John Aalberg    M   33.0   183.0  72.0
# 25   7                    John Aalberg    M   33.0   183.0  72.0
# 28   9                Antti Sami Aalto    M   26.0   186.0  96.0
# 30  11              Jorma Ilmari Aalto    M   22.0   182.0  76.5
# 31  12               Jyri Tapani Aalto    M   31.0   172.0  70.0
# 32  13              Minna Maarit Aalto    F   30.0   159.0  55.5
# 33  13              Minna Maarit Aalto    F   34.0   159.0  55.5
# 34  14  Pirjo Hannele Aalto (Mattila-)    F   32.0   171.0  65.0
# 40  16        Juhamatti Tapio Aaltonen    M   28.0   184.0  85.0
# 41  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 42  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 43  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 44  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 45  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 46  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 47  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 48  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 49  17         Paavo Johannes Aaltonen    M   32.0   175.0  64.0
#
#              Time Sigla        Jogos   Ano Temporada          Cidade  \
# 0           China   CHN  1992 Summer  1992    Summer       Barcelona
# 1           China   CHN  2012 Summer  2012    Summer          London
# 4     Netherlands   NED  1988 Winter  1988    Winter         Calgary
# 5     Netherlands   NED  1988 Winter  1988    Winter         Calgary
# 6     Netherlands   NED  1992 Winter  1992    Winter     Albertville
# 7     Netherlands   NED  1992 Winter  1992    Winter     Albertville
# 8     Netherlands   NED  1994 Winter  1994    Winter     Lillehammer
# 9     Netherlands   NED  1994 Winter  1994    Winter     Lillehammer
# 10  United States   USA  1992 Winter  1992    Winter     Albertville
# 11  United States   USA  1992 Winter  1992    Winter     Albertville
# 12  United States   USA  1992 Winter  1992    Winter     Albertville
# 13  United States   USA  1992 Winter  1992    Winter     Albertville
# 14  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 15  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 16  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 17  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 18  United States   USA  1992 Winter  1992    Winter     Albertville
# 19  United States   USA  1992 Winter  1992    Winter     Albertville
# 20  United States   USA  1992 Winter  1992    Winter     Albertville
# 21  United States   USA  1992 Winter  1992    Winter     Albertville
# 22  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 23  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 24  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 25  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 28        Finland   FIN  2002 Winter  2002    Winter  Salt Lake City
# 30        Finland   FIN  1980 Winter  1980    Winter     Lake Placid
# 31        Finland   FIN  2000 Summer  2000    Summer          Sydney
# 32        Finland   FIN  1996 Summer  1996    Summer         Atlanta
# 33        Finland   FIN  2000 Summer  2000    Summer          Sydney
# 34        Finland   FIN  1994 Winter  1994    Winter     Lillehammer
# 40        Finland   FIN  2014 Winter  2014    Winter           Sochi
# 41        Finland   FIN  1948 Summer  1948    Summer          London
# 42        Finland   FIN  1948 Summer  1948    Summer          London
# 43        Finland   FIN  1948 Summer  1948    Summer          London
# 44        Finland   FIN  1948 Summer  1948    Summer          London
# 45        Finland   FIN  1948 Summer  1948    Summer          London
# 46        Finland   FIN  1948 Summer  1948    Summer          London
# 47        Finland   FIN  1948 Summer  1948    Summer          London
# 48        Finland   FIN  1948 Summer  1948    Summer          London
# 49        Finland   FIN  1952 Summer  1952    Summer        Helsinki
#
#                  Esporte                                             Evento  \
# 0             Basketball                        Basketball Men's Basketball
# 1                   Judo                       Judo Men's Extra-Lightweight
# 4          Speed Skating                   Speed Skating Women's 500 metres
# 5          Speed Skating                 Speed Skating Women's 1,000 metres
# 6          Speed Skating                   Speed Skating Women's 500 metres
# 7          Speed Skating                 Speed Skating Women's 1,000 metres
# 8          Speed Skating                   Speed Skating Women's 500 metres
# 9          Speed Skating                 Speed Skating Women's 1,000 metres
# 10  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 11  Cross Country Skiing           Cross Country Skiing Men's 50 kilometres
# 12  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 13  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 14  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 15  Cross Country Skiing           Cross Country Skiing Men's 30 kilometres
# 16  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 17  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 18  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 19  Cross Country Skiing           Cross Country Skiing Men's 50 kilometres
# 20  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 21  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 22  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 23  Cross Country Skiing           Cross Country Skiing Men's 30 kilometres
# 24  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 25  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 28            Ice Hockey                        Ice Hockey Men's Ice Hockey
# 30  Cross Country Skiing           Cross Country Skiing Men's 30 kilometres
# 31             Badminton                            Badminton Men's Singles
# 32               Sailing                         Sailing Women's Windsurfer
# 33               Sailing                         Sailing Women's Windsurfer
# 34              Biathlon             Biathlon Women's 7.5 kilometres Sprint
# 40            Ice Hockey                        Ice Hockey Men's Ice Hockey
# 41            Gymnastics             Gymnastics Men's Individual All-Around
# 42            Gymnastics                   Gymnastics Men's Team All-Around
# 43            Gymnastics                    Gymnastics Men's Floor Exercise
# 44            Gymnastics                       Gymnastics Men's Horse Vault
# 45            Gymnastics                     Gymnastics Men's Parallel Bars
# 46            Gymnastics                    Gymnastics Men's Horizontal Bar
# 47            Gymnastics                             Gymnastics Men's Rings
# 48            Gymnastics                   Gymnastics Men's Pommelled Horse
# 49            Gymnastics             Gymnastics Men's Individual All-Around
#
#    Medalha         País Observações
# 0      NaN        China         NaN
# 1      NaN        China         NaN
# 4      NaN  Netherlands         NaN
# 5      NaN  Netherlands         NaN
# 6      NaN  Netherlands         NaN
# 7      NaN  Netherlands         NaN
# 8      NaN  Netherlands         NaN
# 9      NaN  Netherlands         NaN
# 10     NaN          USA         NaN
# 11     NaN          USA         NaN
# 12     NaN          USA         NaN
# 13     NaN          USA         NaN
# 14     NaN          USA         NaN
# 15     NaN          USA         NaN
# 16     NaN          USA         NaN
# 17     NaN          USA         NaN
# 18     NaN          USA         NaN
# 19     NaN          USA         NaN
# 20     NaN          USA         NaN
# 21     NaN          USA         NaN
# 22     NaN          USA         NaN
# 23     NaN          USA         NaN
# 24     NaN          USA         NaN
# 25     NaN          USA         NaN
# 28     NaN      Finland         NaN
# 30     NaN      Finland         NaN
# 31     NaN      Finland         NaN
# 32     NaN      Finland         NaN
# 33     NaN      Finland         NaN
# 34     NaN      Finland         NaN
# 40  Bronze      Finland         NaN
# 41  Bronze      Finland         NaN
# 42    Gold      Finland         NaN
# 43     NaN      Finland         NaN
# 44    Gold      Finland         NaN
# 45     NaN      Finland         NaN
# 46     NaN      Finland         NaN
# 47     NaN      Finland         NaN
# 48    Gold      Finland         NaN
# 49     NaN      Finland         NaN

# %%
olim['Time'] = olim['Time'].str.replace('Netherlands','Holanda')

# %%
olim.head(40)
# Out:
#     ID                            Nome Sexo  Idade  Altura  Peso  \
# 0    1                       A Dijiang    M   24.0   180.0  80.0
# 1    2                        A Lamusi    M   23.0   170.0  60.0
# 4    5        Christine Jacoba Aaftink    F   21.0   185.0  82.0
# 5    5        Christine Jacoba Aaftink    F   21.0   185.0  82.0
# 6    5        Christine Jacoba Aaftink    F   25.0   185.0  82.0
# 7    5        Christine Jacoba Aaftink    F   25.0   185.0  82.0
# 8    5        Christine Jacoba Aaftink    F   27.0   185.0  82.0
# 9    5        Christine Jacoba Aaftink    F   27.0   185.0  82.0
# 10   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 11   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 12   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 13   6                 Per Knut Aaland    M   31.0   188.0  75.0
# 14   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 15   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 16   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 17   6                 Per Knut Aaland    M   33.0   188.0  75.0
# 18   7                    John Aalberg    M   31.0   183.0  72.0
# 19   7                    John Aalberg    M   31.0   183.0  72.0
# 20   7                    John Aalberg    M   31.0   183.0  72.0
# 21   7                    John Aalberg    M   31.0   183.0  72.0
# 22   7                    John Aalberg    M   33.0   183.0  72.0
# 23   7                    John Aalberg    M   33.0   183.0  72.0
# 24   7                    John Aalberg    M   33.0   183.0  72.0
# 25   7                    John Aalberg    M   33.0   183.0  72.0
# 28   9                Antti Sami Aalto    M   26.0   186.0  96.0
# 30  11              Jorma Ilmari Aalto    M   22.0   182.0  76.5
# 31  12               Jyri Tapani Aalto    M   31.0   172.0  70.0
# 32  13              Minna Maarit Aalto    F   30.0   159.0  55.5
# 33  13              Minna Maarit Aalto    F   34.0   159.0  55.5
# 34  14  Pirjo Hannele Aalto (Mattila-)    F   32.0   171.0  65.0
# 40  16        Juhamatti Tapio Aaltonen    M   28.0   184.0  85.0
# 41  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 42  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 43  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 44  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 45  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 46  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 47  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 48  17         Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 49  17         Paavo Johannes Aaltonen    M   32.0   175.0  64.0
#
#              Time Sigla        Jogos   Ano Temporada          Cidade  \
# 0           China   CHN  1992 Summer  1992    Summer       Barcelona
# 1           China   CHN  2012 Summer  2012    Summer          London
# 4         Holanda   NED  1988 Winter  1988    Winter         Calgary
# 5         Holanda   NED  1988 Winter  1988    Winter         Calgary
# 6         Holanda   NED  1992 Winter  1992    Winter     Albertville
# 7         Holanda   NED  1992 Winter  1992    Winter     Albertville
# 8         Holanda   NED  1994 Winter  1994    Winter     Lillehammer
# 9         Holanda   NED  1994 Winter  1994    Winter     Lillehammer
# 10  United States   USA  1992 Winter  1992    Winter     Albertville
# 11  United States   USA  1992 Winter  1992    Winter     Albertville
# 12  United States   USA  1992 Winter  1992    Winter     Albertville
# 13  United States   USA  1992 Winter  1992    Winter     Albertville
# 14  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 15  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 16  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 17  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 18  United States   USA  1992 Winter  1992    Winter     Albertville
# 19  United States   USA  1992 Winter  1992    Winter     Albertville
# 20  United States   USA  1992 Winter  1992    Winter     Albertville
# 21  United States   USA  1992 Winter  1992    Winter     Albertville
# 22  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 23  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 24  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 25  United States   USA  1994 Winter  1994    Winter     Lillehammer
# 28        Finland   FIN  2002 Winter  2002    Winter  Salt Lake City
# 30        Finland   FIN  1980 Winter  1980    Winter     Lake Placid
# 31        Finland   FIN  2000 Summer  2000    Summer          Sydney
# 32        Finland   FIN  1996 Summer  1996    Summer         Atlanta
# 33        Finland   FIN  2000 Summer  2000    Summer          Sydney
# 34        Finland   FIN  1994 Winter  1994    Winter     Lillehammer
# 40        Finland   FIN  2014 Winter  2014    Winter           Sochi
# 41        Finland   FIN  1948 Summer  1948    Summer          London
# 42        Finland   FIN  1948 Summer  1948    Summer          London
# 43        Finland   FIN  1948 Summer  1948    Summer          London
# 44        Finland   FIN  1948 Summer  1948    Summer          London
# 45        Finland   FIN  1948 Summer  1948    Summer          London
# 46        Finland   FIN  1948 Summer  1948    Summer          London
# 47        Finland   FIN  1948 Summer  1948    Summer          London
# 48        Finland   FIN  1948 Summer  1948    Summer          London
# 49        Finland   FIN  1952 Summer  1952    Summer        Helsinki
#
#                  Esporte                                             Evento  \
# 0             Basketball                        Basketball Men's Basketball
# 1                   Judo                       Judo Men's Extra-Lightweight
# 4          Speed Skating                   Speed Skating Women's 500 metres
# 5          Speed Skating                 Speed Skating Women's 1,000 metres
# 6          Speed Skating                   Speed Skating Women's 500 metres
# 7          Speed Skating                 Speed Skating Women's 1,000 metres
# 8          Speed Skating                   Speed Skating Women's 500 metres
# 9          Speed Skating                 Speed Skating Women's 1,000 metres
# 10  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 11  Cross Country Skiing           Cross Country Skiing Men's 50 kilometres
# 12  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 13  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 14  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 15  Cross Country Skiing           Cross Country Skiing Men's 30 kilometres
# 16  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 17  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 18  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 19  Cross Country Skiing           Cross Country Skiing Men's 50 kilometres
# 20  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 21  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 22  Cross Country Skiing           Cross Country Skiing Men's 10 kilometres
# 23  Cross Country Skiing           Cross Country Skiing Men's 30 kilometres
# 24  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# 25  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 28            Ice Hockey                        Ice Hockey Men's Ice Hockey
# 30  Cross Country Skiing           Cross Country Skiing Men's 30 kilometres
# 31             Badminton                            Badminton Men's Singles
# 32               Sailing                         Sailing Women's Windsurfer
# 33               Sailing                         Sailing Women's Windsurfer
# 34              Biathlon             Biathlon Women's 7.5 kilometres Sprint
# 40            Ice Hockey                        Ice Hockey Men's Ice Hockey
# 41            Gymnastics             Gymnastics Men's Individual All-Around
# 42            Gymnastics                   Gymnastics Men's Team All-Around
# 43            Gymnastics                    Gymnastics Men's Floor Exercise
# 44            Gymnastics                       Gymnastics Men's Horse Vault
# 45            Gymnastics                     Gymnastics Men's Parallel Bars
# 46            Gymnastics                    Gymnastics Men's Horizontal Bar
# 47            Gymnastics                             Gymnastics Men's Rings
# 48            Gymnastics                   Gymnastics Men's Pommelled Horse
# 49            Gymnastics             Gymnastics Men's Individual All-Around
#
#    Medalha         País Observações
# 0      NaN        China         NaN
# 1      NaN        China         NaN
# 4      NaN  Netherlands         NaN
# 5      NaN  Netherlands         NaN
# 6      NaN  Netherlands         NaN
# 7      NaN  Netherlands         NaN
# 8      NaN  Netherlands         NaN
# 9      NaN  Netherlands         NaN
# 10     NaN          USA         NaN
# 11     NaN          USA         NaN
# 12     NaN          USA         NaN
# 13     NaN          USA         NaN
# 14     NaN          USA         NaN
# 15     NaN          USA         NaN
# 16     NaN          USA         NaN
# 17     NaN          USA         NaN
# 18     NaN          USA         NaN
# 19     NaN          USA         NaN
# 20     NaN          USA         NaN
# 21     NaN          USA         NaN
# 22     NaN          USA         NaN
# 23     NaN          USA         NaN
# 24     NaN          USA         NaN
# 25     NaN          USA         NaN
# 28     NaN      Finland         NaN
# 30     NaN      Finland         NaN
# 31     NaN      Finland         NaN
# 32     NaN      Finland         NaN
# 33     NaN      Finland         NaN
# 34     NaN      Finland         NaN
# 40  Bronze      Finland         NaN
# 41  Bronze      Finland         NaN
# 42    Gold      Finland         NaN
# 43     NaN      Finland         NaN
# 44    Gold      Finland         NaN
# 45     NaN      Finland         NaN
# 46     NaN      Finland         NaN
# 47     NaN      Finland         NaN
# 48    Gold      Finland         NaN
# 49     NaN      Finland         NaN

# %%
olim.groupby(['Medalha']).count()
# Out:
#             ID   Nome   Sexo  Idade  Altura   Peso   Time  Sigla  Jogos  \
# Medalha
# Bronze   10148  10148  10148  10148   10148  10148  10148  10148  10148
# Gold     10167  10167  10167  10167   10167  10167  10167  10167  10167
# Silver    9866   9866   9866   9866    9866   9866   9866   9866   9866
#
#            Ano  Temporada  Cidade  Esporte  Evento   País  Observações
# Medalha
# Bronze   10148      10148   10148    10148   10148  10144          133
# Gold     10167      10167   10167    10167   10167  10166          143
# Silver    9866       9866    9866     9866    9866   9862          154

# %%
olim.groupby(['Sexo']).count()
# Out:
#           ID    Nome   Idade  Altura    Peso    Time   Sigla   Jogos     Ano  \
# Sexo
# F      66711   66711   66711   66711   66711   66711   66711   66711   66711
# M     139441  139441  139441  139441  139441  139441  139441  139441  139441
#
#       Temporada  Cidade  Esporte  Evento  Medalha    País  Observações
# Sexo
# F         66711   66711    66711   66711    10350   66592          724
# M        139441  139441   139441  139441    19831  139290         2769

# %%
olim.groupby(['Medalha'])['Idade'].sum()
# Out:
# Medalha
# Bronze    258712.0
# Gold      257537.0
# Silver    251224.0
# Name: Idade, dtype: float64

# %%
olim.groupby(['Medalha'])['Idade'].count()
# Out:
# Medalha
# Bronze    10148
# Gold      10167
# Silver     9866
# Name: Idade, dtype: int64

# %%
olim.groupby(['País'])['Medalha'].count()
# Out:
# País
# Afghanistan                 2
# Albania                     0
# Algeria                    15
# American Samoa              0
# Andorra                     0
#                            ..
# Virgin Islands, British     0
# Virgin Islands, US          1
# Yemen                       0
# Zambia                      1
# Zimbabwe                   22
# Name: Medalha, Length: 205, dtype: int64

# %%
olimpiadas = olim

# %%
olimpiadas.shape
# Out:
# (206152, 17)

# %%
olimpiadas.head(3)
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso     Time Sigla  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0    China   CHN
# 1   2                  A Lamusi    M   23.0   170.0  60.0    China   CHN
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0  Holanda   NED
#
#          Jogos   Ano Temporada     Cidade        Esporte  \
# 0  1992 Summer  1992    Summer  Barcelona     Basketball
# 1  2012 Summer  2012    Summer     London           Judo
# 4  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                              Evento Medalha         País Observações
# 0       Basketball Men's Basketball     NaN        China         NaN
# 1      Judo Men's Extra-Lightweight     NaN        China         NaN
# 4  Speed Skating Women's 500 metres     NaN  Netherlands         NaN

# %%
olimpiadas =olimpiadas.drop(columns=['ID','Nome','Peso','Altura','Idade','Sexo'])

# %%
olimpiadas.head(3)
# Out:
#       Time Sigla        Jogos   Ano Temporada     Cidade        Esporte  \
# 0    China   CHN  1992 Summer  1992    Summer  Barcelona     Basketball
# 1    China   CHN  2012 Summer  2012    Summer     London           Judo
# 4  Holanda   NED  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                              Evento Medalha         País Observações
# 0       Basketball Men's Basketball     NaN        China         NaN
# 1      Judo Men's Extra-Lightweight     NaN        China         NaN
# 4  Speed Skating Women's 500 metres     NaN  Netherlands         NaN

# %%
olimpiadas.shape
# Out:
# (206152, 11)

# %%
olimpiadas = olimpiadas.drop_duplicates()

# %%
olimpiadas.shape
# Out:
# (102853, 11)

# %%
olimpiadas [(olimpiadas['Sigla'] == 'BRA') & (olimpiadas['Medalha'] == 'Gold')].groupby(['Ano','Esporte','Medalha']).count()
# Out:
#                                Time  Sigla  Jogos  Temporada  Cidade  Evento  \
# Ano  Esporte          Medalha
# 1952 Athletics        Gold        1      1      1          1       1       1
# 1956 Athletics        Gold        1      1      1          1       1       1
# 1980 Sailing          Gold        2      2      2          2       2       2
# 1984 Athletics        Gold        1      1      1          1       1       1
# 1988 Judo             Gold        1      1      1          1       1       1
# 1992 Volleyball       Gold        1      1      1          1       1       1
# 1996 Beach Volleyball Gold        1      1      1          1       1       1
#      Sailing          Gold        2      2      2          2       2       2
# 2004 Beach Volleyball Gold        1      1      1          1       1       1
#      Equestrianism    Gold        1      1      1          1       1       1
#      Sailing          Gold        2      2      2          2       2       2
#      Volleyball       Gold        1      1      1          1       1       1
# 2008 Athletics        Gold        1      1      1          1       1       1
#      Swimming         Gold        1      1      1          1       1       1
#      Volleyball       Gold        1      1      1          1       1       1
# 2012 Gymnastics       Gold        1      1      1          1       1       1
#      Judo             Gold        1      1      1          1       1       1
#      Volleyball       Gold        1      1      1          1       1       1
# 2016 Athletics        Gold        1      1      1          1       1       1
#      Beach Volleyball Gold        1      1      1          1       1       1
#      Boxing           Gold        1      1      1          1       1       1
#      Football         Gold        1      1      1          1       1       1
#      Judo             Gold        1      1      1          1       1       1
#      Sailing          Gold        1      1      1          1       1       1
#      Volleyball       Gold        1      1      1          1       1       1
#
#                                País  Observações
# Ano  Esporte          Medalha
# 1952 Athletics        Gold        1            0
# 1956 Athletics        Gold        1            0
# 1980 Sailing          Gold        2            0
# 1984 Athletics        Gold        1            0
# 1988 Judo             Gold        1            0
# 1992 Volleyball       Gold        1            0
# 1996 Beach Volleyball Gold        1            0
#      Sailing          Gold        2            0
# 2004 Beach Volleyball Gold        1            0
#      Equestrianism    Gold        1            0
#      Sailing          Gold        2            0
#      Volleyball       Gold        1            0
# 2008 Athletics        Gold        1            0
#      Swimming         Gold        1            0
#      Volleyball       Gold        1            0
# 2012 Gymnastics       Gold        1            0
#      Judo             Gold        1            0
#      Volleyball       Gold        1            0
# 2016 Athletics        Gold        1            0
#      Beach Volleyball Gold        1            0
#      Boxing           Gold        1            0
#      Football         Gold        1            0
#      Judo             Gold        1            0
#      Sailing          Gold        1            0
#      Volleyball       Gold        1            0

# %%
olimpiadas [(olimpiadas['Sigla'] == 'BRA') & (olimpiadas['Medalha'] == 'Gold')].groupby(['Ano','Medalha']).count()
# Out:
#               Time  Sigla  Jogos  Temporada  Cidade  Esporte  Evento  País  \
# Ano  Medalha
# 1952 Gold        1      1      1          1       1        1       1     1
# 1956 Gold        1      1      1          1       1        1       1     1
# 1980 Gold        2      2      2          2       2        2       2     2
# 1984 Gold        1      1      1          1       1        1       1     1
# 1988 Gold        1      1      1          1       1        1       1     1
# 1992 Gold        1      1      1          1       1        1       1     1
# 1996 Gold        3      3      3          3       3        3       3     3
# 2004 Gold        5      5      5          5       5        5       5     5
# 2008 Gold        3      3      3          3       3        3       3     3
# 2012 Gold        3      3      3          3       3        3       3     3
# 2016 Gold        7      7      7          7       7        7       7     7
#
#               Observações
# Ano  Medalha
# 1952 Gold               0
# 1956 Gold               0
# 1980 Gold               0
# 1984 Gold               0
# 1988 Gold               0
# 1992 Gold               0
# 1996 Gold               0
# 2004 Gold               0
# 2008 Gold               0
# 2012 Gold               0
# 2016 Gold               0

# %%
olimpiadas[(olimpiadas['Sigla'] == 'BRA') & (olimpiadas['Medalha'] == 'Gold')].groupby(['Ano'])[['Medalha']].count().plot()
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo = olimpiadas[(olimpiadas['Sigla'] == 'BRA') & (olimpiadas['Medalha'] == 'Gold')].groupby(['Ano'])[['Medalha']].count()

# %%
resumo.head()
# Out:
#       Medalha
# Ano
# 1952        1
# 1956        1
# 1980        2
# 1984        1
# 1988        1

# %%
resumo.plot(kind='bar')
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo.plot(kind='barh')
# Out:
# <Axes: ylabel='Ano'>

# %%
resumo.plot(kind='bar', figsize=(11,5))
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo.plot(kind='bar', figsize=(11,5))
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo.plot(kind='bar', figsize=(11,5), grid=True)
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo.plot(kind='bar', figsize=(11,5), grid=True, rot=45, color='red')
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo.plot(kind='bar', figsize=(11,5), grid=True, rot=45, color='black')
# Out:
# <Axes: xlabel='Ano'>

# %%
resumo.plot(kind='bar', figsize=(11,5), grid=True, rot=45, color='black', title='Categorias por ano')
# Out:
# <Axes: title={'center': 'Categorias por ano'}, xlabel='Ano'>

# %%
resumo.sort_values(by = 'Medalha')
# Out:
#       Medalha
# Ano
# 1952        1
# 1956        1
# 1984        1
# 1988        1
# 1992        1
# 1980        2
# 1996        3
# 2008        3
# 2012        3
# 2004        5
# 2016        7

# %%
resumo.sort_values(by = 'Medalha', ascending = False)
# Out:
#       Medalha
# Ano
# 2016        7
# 2004        5
# 1996        3
# 2008        3
# 2012        3
# 1980        2
# 1952        1
# 1956        1
# 1984        1
# 1988        1
# 1992        1

# %%
resumo.sort_values(by = 'Medalha', ascending=False).plot(kind='bar', figsize=(11,5), grid=True, rot=45, color='black', title='Categorias por ano')
# Out:
# <Axes: title={'center': 'Categorias por ano'}, xlabel='Ano'>

# %%
olimpiadas[(olimpiadas['Sigla'] == 'BRA') & (olimpiadas['Medalha'] == 'Gold')].groupby(['Ano'])[['Medalha']].count()
# Out:
#       Medalha
# Ano
# 1952        1
# 1956        1
# 1980        2
# 1984        1
# 1988        1
# 1992        1
# 1996        3
# 2004        5
# 2008        3
# 2012        3
# 2016        7

# %%
olimpiadas[(olimpiadas['Sigla'] == 'BRA')].groupby(['Ano','Medalha'])[['Medalha']].count()
# Out:
#               Medalha
# Ano  Medalha
# 1948 Bronze         1
# 1952 Bronze         1
#      Gold           1
# 1956 Gold           1
# 1960 Bronze         1
# 1964 Bronze         1
# 1968 Bronze         2
#      Silver         1
# 1972 Bronze         2
# 1976 Bronze         2
# 1980 Bronze         2
#      Gold           2
# 1984 Bronze         2
#      Gold           1
#      Silver         5
# 1988 Bronze         3
#      Gold           1
#      Silver         2
# 1992 Gold           1
#      Silver         1
# 1996 Bronze         9
#      Gold           3
#      Silver         3
# 2000 Bronze         6
#      Silver         6
# 2004 Bronze         3
#      Gold           5
#      Silver         2
# 2008 Bronze         9
#      Gold           3
#      Silver         4
# 2012 Bronze         9
#      Gold           3
#      Silver         5
# 2016 Bronze         6
#      Gold           7
#      Silver         6

# %%
olimpiadas[(olimpiadas['Sigla'] == 'BRA')].groupby(['Medalha'])[['Medalha']].count()
# Out:
#          Medalha
# Medalha
# Bronze        59
# Gold          28
# Silver        35

# %%
olimpiadas[(olimpiadas['Sigla'] == 'BRA')].groupby(['Medalha'])[['Medalha']].count()
# Out:
#          Medalha
# Medalha
# Bronze        59
# Gold          28
# Silver        35

# %%
resumoP = olimpiadas[(olimpiadas['Sigla'] == 'BRA')].groupby(['Medalha'])[['Medalha']].count()

# %%
resumoP.head()
# Out:
#          Medalha
# Medalha
# Bronze        59
# Gold          28
# Silver        35

# %%
resumoP.plot(kind='pie', subplots=True)
# Out:
# array([<Axes: ylabel='Medalha'>], dtype=object)

# %%
resumoP.plot(kind='pie', subplots=True, explode=(0,0.1,0))
# Out:
# array([<Axes: ylabel='Medalha'>], dtype=object)

# %%
resumoP.plot(kind='pie', subplots=True, explode=(0.1,0,0))
# Out:
# array([<Axes: ylabel='Medalha'>], dtype=object)

# %%
olim.groupby(['Sigla'])['Altura'].max()
# Out:
# Sigla
# AFG    186.0
# AHO    193.0
# ALB    195.0
# ALG    200.0
# AND    189.0
#        ...
# YEM    185.0
# YMD    175.0
# YUG    217.0
# ZAM    190.0
# ZIM    205.0
# Name: Altura, Length: 226, dtype: float64

# %%
olim.groupby(['País'])['Altura'].max()
# Out:
# País
# Afghanistan                186.0
# Albania                    195.0
# Algeria                    200.0
# American Samoa             188.0
# Andorra                    189.0
#                            ...
# Virgin Islands, British    196.0
# Virgin Islands, US         198.0
# Yemen                      185.0
# Zambia                     190.0
# Zimbabwe                   205.0
# Name: Altura, Length: 205, dtype: float64

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['País'])['Altura'].max()
# Out:
# País
# Brazil    217.0
# Name: Altura, dtype: float64

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura'].max()
# Out:
# Ano   País
# 1924  Brazil    181.0
# 1932  Brazil    183.0
# 1936  Brazil    183.0
# 1948  Brazil    185.0
# 1952  Brazil    195.0
# 1956  Brazil    195.0
# 1960  Brazil    200.0
# 1964  Brazil    200.0
# 1968  Brazil    201.0
# 1972  Brazil    204.0
# 1976  Brazil    199.0
# 1980  Brazil    205.0
# 1984  Brazil    207.0
# 1988  Brazil    217.0
# 1992  Brazil    217.0
# 1994  Brazil    188.0
# 1996  Brazil    211.0
# 2000  Brazil    203.0
# 2002  Brazil    192.0
# 2004  Brazil    205.0
# 2006  Brazil    190.0
# 2008  Brazil    205.0
# 2010  Brazil    184.0
# 2012  Brazil    212.0
# 2014  Brazil    190.0
# 2016  Brazil    211.0
# Name: Altura, dtype: float64

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura'].max().plot()
# Out:
# <Axes: xlabel='Ano,País'>

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura'].max().plot(kind='bar')
# Out:
# <Axes: xlabel='Ano,País'>

# %%
altura = olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura'].max()

# %%
altura.plot(kind='bar', figsize=(11,5))
# Out:
# <Axes: xlabel='Ano,País'>

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura'].mean()
# Out:
# Ano   País
# 1924  Brazil    181.000000
# 1932  Brazil    179.000000
# 1936  Brazil    178.250000
# 1948  Brazil    182.666667
# 1952  Brazil    180.214286
# 1956  Brazil    181.352941
# 1960  Brazil    179.904762
# 1964  Brazil    184.966667
# 1968  Brazil    180.541176
# 1972  Brazil    181.206186
# 1976  Brazil    178.922078
# 1980  Brazil    180.713178
# 1984  Brazil    181.012739
# 1988  Brazil    182.194444
# 1992  Brazil    184.304965
# 1994  Brazil    188.000000
# 1996  Brazil    184.066667
# 2000  Brazil    182.646617
# 2002  Brazil    181.875000
# 2004  Brazil    182.481013
# 2006  Brazil    183.888889
# 2008  Brazil    182.552326
# 2010  Brazil    180.000000
# 2012  Brazil    183.556250
# 2014  Brazil    182.428571
# 2016  Brazil    181.509317
# Name: Altura, dtype: float64

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura'].mean().plot(kind='bar', figsize=(11,5))
# Out:
# <Axes: xlabel='Ano,País'>

# %%
olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura','Peso'].mean().plot(figsize=(11,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 olim[(olim['Sexo'] == 'M') & (olim['Sigla'] == 'BRA')].groupby(['Ano','País'])['Altura','Peso'].mean().plot(figsize=(11,5))
#
# File c:\Users\rafae\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1960, in DataFrameGroupBy.__getitem__(self, key)
#    1956 # per GH 23566
#    1957 if isinstance(key, tuple) and len(key) > 1:
#    1958     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1959     # valid syntax, so don't raise
# -> 1960     raise ValueError(
#    1961         "Cannot subset columns with a tuple with more than one element. "
#    1962         "Use a list instead."
#    1963     )
#    1964 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
olim.plot.scatter(x='Ano',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Ano', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA')].plot.scatter(x='Ano',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Ano', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Volleyball')].plot.scatter(x='Ano',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Ano', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Volleyball')].plot.scatter(x='Peso',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Volleyball')].plot.scatter(x='Idade',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Idade', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA')].plot.scatter(x='Peso',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Volleyball')].plot.scatter(x='Peso',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
olim['Esporte'].unique()
# Out:
# array(['Basketball', 'Judo', 'Speed Skating', 'Cross Country Skiing',
#        'Ice Hockey', 'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Athletics', 'Alpine Skiing', 'Weightlifting', 'Wrestling', 'Luge',
#        'Rowing', 'Bobsleigh', 'Swimming', 'Football', 'Equestrianism',
#        'Shooting', 'Taekwondo', 'Boxing', 'Fencing', 'Diving', 'Canoeing',
#        'Handball', 'Water Polo', 'Tennis', 'Cycling', 'Hockey',
#        'Figure Skating', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Modern Pentathlon', 'Table Tennis',
#        'Nordic Combined', 'Baseball', 'Rhythmic Gymnastics',
#        'Freestyle Skiing', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Ski Jumping', 'Curling', 'Golf',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton', 'Rugby',
#        'Tug-Of-War', 'Art Competitions', 'Lacrosse', 'Motorboating'],
#       dtype=object)

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Athletics')].plot.scatter(x='Peso',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Athletics') |  (olim['Esporte'] == 'Volleyball')].plot.scatter(x='Peso',y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
colorido = olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & (olim['Esporte'] == 'Athletics') |  (olim['Esporte'] == 'Volleyball')]

# %%
colorido.head()
# Out:
#       ID                  Nome Sexo  Idade  Altura  Peso   Time Sigla  \
# 291  156  Mahmoud Abd El-Kader    M   23.0   195.0  94.0  Egypt   EGY
# 299  161        Hossam Abdalla    M   28.0   203.0  97.0  Egypt   EGY
# 318  171    Mahmoud Abdel Aziz    M   25.0   174.0  70.0  Egypt   EGY
# 342  188   Mohamed Abdel Hamed    M   24.0   193.0  82.0  Egypt   EGY
# 365  203     Ahmed Abdel Naeim    M   23.0   197.0  87.0  Egypt   EGY
#
#            Jogos   Ano Temporada          Cidade     Esporte  \
# 291  2008 Summer  2008    Summer         Beijing  Volleyball
# 299  2016 Summer  2016    Summer  Rio de Janeiro  Volleyball
# 318  2000 Summer  2000    Summer          Sydney  Volleyball
# 342  1984 Summer  1984    Summer     Los Angeles  Volleyball
# 365  2008 Summer  2008    Summer         Beijing  Volleyball
#
#                           Evento Medalha   País Observações
# 291  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 299  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 318  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 342  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 365  Volleyball Men's Volleyball     NaN  Egypt         NaN

# %%
colorido.head()
# Out:
#       ID                  Nome Sexo  Idade  Altura  Peso   Time Sigla  \
# 291  156  Mahmoud Abd El-Kader    M   23.0   195.0  94.0  Egypt   EGY
# 299  161        Hossam Abdalla    M   28.0   203.0  97.0  Egypt   EGY
# 318  171    Mahmoud Abdel Aziz    M   25.0   174.0  70.0  Egypt   EGY
# 342  188   Mohamed Abdel Hamed    M   24.0   193.0  82.0  Egypt   EGY
# 365  203     Ahmed Abdel Naeim    M   23.0   197.0  87.0  Egypt   EGY
#
#            Jogos   Ano Temporada          Cidade     Esporte  \
# 291  2008 Summer  2008    Summer         Beijing  Volleyball
# 299  2016 Summer  2016    Summer  Rio de Janeiro  Volleyball
# 318  2000 Summer  2000    Summer          Sydney  Volleyball
# 342  1984 Summer  1984    Summer     Los Angeles  Volleyball
# 365  2008 Summer  2008    Summer         Beijing  Volleyball
#
#                           Evento Medalha   País Observações
# 291  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 299  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 318  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 342  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 365  Volleyball Men's Volleyball     NaN  Egypt         NaN

# %%
colorido.head(5)
# Out:
#       ID                  Nome Sexo  Idade  Altura  Peso   Time Sigla  \
# 291  156  Mahmoud Abd El-Kader    M   23.0   195.0  94.0  Egypt   EGY
# 299  161        Hossam Abdalla    M   28.0   203.0  97.0  Egypt   EGY
# 318  171    Mahmoud Abdel Aziz    M   25.0   174.0  70.0  Egypt   EGY
# 342  188   Mohamed Abdel Hamed    M   24.0   193.0  82.0  Egypt   EGY
# 365  203     Ahmed Abdel Naeim    M   23.0   197.0  87.0  Egypt   EGY
#
#            Jogos   Ano Temporada          Cidade     Esporte  \
# 291  2008 Summer  2008    Summer         Beijing  Volleyball
# 299  2016 Summer  2016    Summer  Rio de Janeiro  Volleyball
# 318  2000 Summer  2000    Summer          Sydney  Volleyball
# 342  1984 Summer  1984    Summer     Los Angeles  Volleyball
# 365  2008 Summer  2008    Summer         Beijing  Volleyball
#
#                           Evento Medalha   País Observações
# 291  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 299  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 318  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 342  Volleyball Men's Volleyball     NaN  Egypt         NaN
# 365  Volleyball Men's Volleyball     NaN  Egypt         NaN

# %%
colorido = olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & ((olim['Esporte'] == 'Athletics') | (olim['Esporte'] == 'Volleyball'))]

# %%
colorido.head(10)
# Out:
#         ID                            Nome Sexo  Idade  Altura  Peso    Time  \
# 665    386                 Alexandre Abeid    M   22.0   194.0  92.0  Brazil
# 666    386                 Alexandre Abeid    M   26.0   194.0  92.0  Brazil
# 5714  3221               Higor Silva Alves    M   22.0   183.0  64.0  Brazil
# 5720  3227             Thiago Soares Alves    M   25.0   194.0  88.0  Brazil
# 5927  3330                  Amauri Ribeiro    M   21.0   198.0  87.0  Brazil
# 5928  3330                  Amauri Ribeiro    M   25.0   198.0  87.0  Brazil
# 5929  3330                  Amauri Ribeiro    M   29.0   198.0  87.0  Brazil
# 5930  3330                  Amauri Ribeiro    M   33.0   198.0  87.0  Brazil
# 6760  3790  Anderson de Oliveira Rodrigues    M   30.0   190.0  95.0  Brazil
# 6761  3790  Anderson de Oliveira Rodrigues    M   34.0   190.0  95.0  Brazil
#
#      Sigla        Jogos   Ano Temporada          Cidade     Esporte  \
# 665    BRA  1972 Summer  1972    Summer          Munich  Volleyball
# 666    BRA  1976 Summer  1976    Summer        Montreal  Volleyball
# 5714   BRA  2016 Summer  2016    Summer  Rio de Janeiro   Athletics
# 5720   BRA  2012 Summer  2012    Summer          London  Volleyball
# 5927   BRA  1980 Summer  1980    Summer          Moskva  Volleyball
# 5928   BRA  1984 Summer  1984    Summer     Los Angeles  Volleyball
# 5929   BRA  1988 Summer  1988    Summer           Seoul  Volleyball
# 5930   BRA  1992 Summer  1992    Summer       Barcelona  Volleyball
# 6760   BRA  2004 Summer  2004    Summer          Athina  Volleyball
# 6761   BRA  2008 Summer  2008    Summer         Beijing  Volleyball
#
#                            Evento Medalha    País Observações
# 665   Volleyball Men's Volleyball     NaN  Brazil         NaN
# 666   Volleyball Men's Volleyball     NaN  Brazil         NaN
# 5714    Athletics Men's Long Jump     NaN  Brazil         NaN
# 5720  Volleyball Men's Volleyball  Silver  Brazil         NaN
# 5927  Volleyball Men's Volleyball     NaN  Brazil         NaN
# 5928  Volleyball Men's Volleyball  Silver  Brazil         NaN
# 5929  Volleyball Men's Volleyball     NaN  Brazil         NaN
# 5930  Volleyball Men's Volleyball    Gold  Brazil         NaN
# 6760  Volleyball Men's Volleyball    Gold  Brazil         NaN
# 6761  Volleyball Men's Volleyball  Silver  Brazil         NaN

# %%
colorido.plot.scatter(x='Peso', y='Altura', c='DarkBlue')
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
colormap = {'Volleyball':'blue','Athletics':'red'}
cores = [colormap[x] for x in colorido['Esporte']]
colorido.plot.scatter(x='Peso', y= 'Altura', color=cores)
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
colorido = olim[(olim['Sexo']=='M') &( olim['Sigla'] == 'BRA') & ((olim['Esporte'] == 'Athletics') | (olim['Esporte'] == 'Volleyball') | (olim['Esporte']=='Tennis'))]

# %%
colorido.head(5)
# Out:
#         ID                           Nome Sexo  Idade  Altura  Peso    Time  \
# 665    386                Alexandre Abeid    M   22.0   194.0  92.0  Brazil
# 666    386                Alexandre Abeid    M   26.0   194.0  92.0  Brazil
# 1235   695  Ricardo Augusto Amaral Acioly    M   24.0   179.0  78.0  Brazil
# 5714  3221              Higor Silva Alves    M   22.0   183.0  64.0  Brazil
# 5720  3227            Thiago Soares Alves    M   25.0   194.0  88.0  Brazil
#
#      Sigla        Jogos   Ano Temporada          Cidade     Esporte  \
# 665    BRA  1972 Summer  1972    Summer          Munich  Volleyball
# 666    BRA  1976 Summer  1976    Summer        Montreal  Volleyball
# 1235   BRA  1988 Summer  1988    Summer           Seoul      Tennis
# 5714   BRA  2016 Summer  2016    Summer  Rio de Janeiro   Athletics
# 5720   BRA  2012 Summer  2012    Summer          London  Volleyball
#
#                            Evento Medalha    País Observações
# 665   Volleyball Men's Volleyball     NaN  Brazil         NaN
# 666   Volleyball Men's Volleyball     NaN  Brazil         NaN
# 1235         Tennis Men's Doubles     NaN  Brazil         NaN
# 5714    Athletics Men's Long Jump     NaN  Brazil         NaN
# 5720  Volleyball Men's Volleyball  Silver  Brazil         NaN

# %%
colormap = {'Volleyball':'blue','Athletics':'red','Tennis':'green'}
cores = [colormap[x] for x in colorido['Esporte']]
colorido.plot.scatter(x='Peso', y= 'Altura', color=cores)
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
colormap = {'Volleyball':'yellow','Athletics':'red','Tennis':'blue'}
cores = [colormap[x] for x in colorido['Esporte']]
colorido.plot.scatter(x='Peso', y= 'Altura', color=cores)
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
colormap = {'Volleyball':'green','Athletics':'red','Tennis':'blue'}
cores = [colormap[x] for x in colorido['Esporte']]
colorido.plot.scatter(x='Peso', y= 'Altura', color=cores)
# Out:
# <Axes: xlabel='Peso', ylabel='Altura'>

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafae\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rafae\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rafae\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rafae\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 262.6 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.9 kB 281.8 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.9 kB 328.6 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
