# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeel-albuquerque/datasciensecoursefinal/blob/main/Aprendendo_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Passo 01- Importando o Pandas

# %%
import pandas as pd

# %% [markdown]
# Passo 02 - Criando Dataframe

# %%
#DataFrame=pd.DataFrame() --> Sintaxe
venda ={'Data':['15/02/2021', '16/02/2021'],
        'Valor': [500,300],
        'Produto': ['Arroz','Feijão'],
        'Qtde' :[50,70],
        }

vendas_df =pd.DataFrame(venda)
print(vendas_df)
# Out:
#          Data  Valor Produto  Qtde
# 0  15/02/2021    500   Arroz    50
# 1  16/02/2021    300  Feijão    70

# %%
Passo 03 - Visualizando dados do pd.DataFrame

# %%
display(vendas_df)
# Out:
#          Data  Valor Produto  Qtde
# 0  15/02/2021    500   Arroz    50
# 1  16/02/2021    300  Feijão    70

# %% [markdown]
# Passo 04 - Importando base de dados do Excel

# %%
vendas_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data Python 2412/Bases Panda/Vendas.xlsx')
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %% [markdown]
# Passo 05 - Visualização de arquivos e base de dados

# %%
display(vendas_df.head(10))
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# ...

# %%
print(vendas_df.shape)
# Out:
# (93910, 7)

# %%
display(vendas_df.describe())
# Out:
#        Código Venda                           Data    Quantidade  \
# count  93910.000000                          93910  93910.000000
# mean   32464.762155  2019-06-16 23:52:28.265360896      2.166553
# min        1.000000            2019-01-01 00:00:00      1.000000
# 25%    16204.000000            2019-03-26 00:00:00      1.000000
# 50%    32367.000000            2019-06-17 00:00:00      2.000000
# 75%    48793.750000            2019-09-08 00:00:00      3.000000
# max    65014.000000            2019-11-30 00:00:00      5.000000
# std    18809.007093                            NaN      1.258732
#
#        Valor Unitário   Valor Final
# count    93910.000000  93910.000000
# mean       191.725886    414.862656
# min         30.000000     30.000000
# 25%        100.000000    156.000000
# 50%        155.000000    274.000000
# 75%        248.000000    524.000000
# max        750.000000   3750.000000
# std        145.215519    434.846228

# %% [markdown]
# Passo 06 - Edição de DataFrame

# %%
produtos = vendas_df['Produto']
display(produtos)
# Out:
# 0           Sapato Estampa
# 1                 Camiseta
# 2            Sapato Xadrez
# 3                  Relógio
# 4             Chinelo Liso
#                ...
# 93905       Mochila Xadrez
# 93906    Pulseira Listrado
# 93907       Cueca Listrado
# 93908       Pulseira Linho
# 93909        Casaco Xadrez
# Name: Produto, Length: 93910, dtype: object

# %%
produtos = vendas_df[['Produto','ID Loja']]
display(produtos)
# Out:
#                  Produto              ID Loja
# 0         Sapato Estampa   Iguatemi Esplanada
# 1               Camiseta   Iguatemi Esplanada
# 2          Sapato Xadrez   Iguatemi Esplanada
# 3                Relógio       Norte Shopping
# 4           Chinelo Liso       Norte Shopping
# ...                  ...                  ...
# 93905     Mochila Xadrez  Shopping Vila Velha
# 93906  Pulseira Listrado    Ribeirão Shopping
# 93907     Cueca Listrado    Ribeirão Shopping
# 93908     Pulseira Linho     Shopping Morumbi
# 93909      Casaco Xadrez     Shopping Morumbi
#
# [93910 rows x 2 columns]

# %%
display(vendas_df.loc[1])
# Out:
# Código Venda                        1
# Data              2019-01-01 00:00:00
# ID Loja            Iguatemi Esplanada
# Produto                      Camiseta
# Quantidade                          2
# Valor Unitário                    180
# Valor Final                       360
# Name: 1, dtype: object

# %%
display(vendas_df.loc[20:25])
# Out:
#     Código Venda       Data                     ID Loja           Produto  \
# 20            14 2019-01-02         Bourbon Shopping SP       Casaco Liso
# 21            17 2019-01-02           Iguatemi Campinas      Chinelo Liso
# 22            18 2019-01-02  Rio Mar Shopping Fortaleza    Camisa Estampa
# 23            19 2019-01-02   Passei das Águas Shopping  Relógio Listrado
# 24            19 2019-01-02   Passei das Águas Shopping       Calça Linho
# 25            20 2019-01-02  Shopping Center Interlagos      Mochila Liso
#
#     Quantidade  Valor Unitário  Valor Final
# 20           2             255          510
# 21           1              71           71
# 22           1             113          113
# 23           1             218          218
# 24           2             211          422
# 25           1             276          276

# %%
display(vendas_df.loc[vendas_df['ID Loja']=='Shopping Center Interlagos'])
# Out:
#        Código Venda       Data                     ID Loja  \
# 25               20 2019-01-02  Shopping Center Interlagos
# 145             112 2019-01-02  Shopping Center Interlagos
# 146             112 2019-01-02  Shopping Center Interlagos
# 179             135 2019-01-02  Shopping Center Interlagos
# 180             135 2019-01-02  Shopping Center Interlagos
# ...             ...        ...                         ...
# 93803         64944 2019-11-30  Shopping Center Interlagos
# 93805         64946 2019-11-30  Shopping Center Interlagos
# 93806         64946 2019-11-30  Shopping Center Interlagos
# 93836         64969 2019-11-30  Shopping Center Interlagos
# 93903         65011 2019-11-30  Shopping Center Interlagos
#
#                    Produto  Quantidade  Valor Unitário  Valor Final
# 25            Mochila Liso           1             276          276
# 145         Calça Listrado           2             181          362
# ...

# %%
display(vendas_df.loc[vendas_df['ID Loja']=='Norte Shopping', ['ID Loja', 'Produto','Quantidade']])
# Out:
#               ID Loja                 Produto  Quantidade
# 3      Norte Shopping                 Relógio           3
# 4      Norte Shopping            Chinelo Liso           1
# 8      Norte Shopping  Camisa Gola V Listrado           1
# 9      Norte Shopping             Camisa Liso           1
# 100    Norte Shopping            Cueca Xadrez           5
# ...               ...                     ...         ...
# 93716  Norte Shopping             Polo Xadrez           1
# 93754  Norte Shopping              Calça Liso           1
# 93755  Norte Shopping          Casaco Estampa           2
# 93756  Norte Shopping                   Gorro           2
# 93852  Norte Shopping           Bermuda Linho           1
#
# [3924 rows x 3 columns]

# %%
display(vendas_df.loc[vendas_df['ID Loja']=='Shopping Center Interlagos', ['ID Loja', 'Produto','Quantidade']])
# Out:
#                           ID Loja              Produto  Quantidade
# 25     Shopping Center Interlagos         Mochila Liso           1
# 145    Shopping Center Interlagos       Calça Listrado           2
# 146    Shopping Center Interlagos  Camisa Gola V Linho           2
# 179    Shopping Center Interlagos       Mochila Xadrez           3
# 180    Shopping Center Interlagos       Camisa Estampa           1
# ...                           ...                  ...         ...
# 93803  Shopping Center Interlagos        Camisa Xadrez           1
# 93805  Shopping Center Interlagos          Tênis Linho           1
# 93806  Shopping Center Interlagos      Mochila Estampa           2
# 93836  Shopping Center Interlagos          Cinto Linho           3
# 93903  Shopping Center Interlagos       Chinelo Xadrez           2
#
# [3767 rows x 3 columns]

# %% [markdown]
# ## Passo 07 - Adcionar Coluna
